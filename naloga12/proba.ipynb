# %% [markdown]
# ## Probam dat not gnuplot slikice
# Recimo nek enostaven grafek

# %%
%load_ext gnuplot_kernel
%%gnuplot
set xrange [-5:5]
g(x) = 1/(sqrt(2*pi)*sigma) * exp(-x**2/sigma**2)
plot sigma=2 g(x) lc 6 lw 2,\
     sigma=0.5 g(x) lc 4 lw 2
# Out:
# ...
#          ^
#          invalid command
#
#          ^
#          invalid command
#
# [?
